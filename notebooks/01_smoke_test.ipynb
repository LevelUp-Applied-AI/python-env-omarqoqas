# %%
import numpy as np 
import pandas as pd

df = pd.read_csv("../data/sample.csv")
print("Shape:", df.shape)
print(df.head())
print(df.describe())
# Out:
# Shape: (6, 3)
#     name  score  passed
# 0  Alice     85    True
# 1    Bob     72    True
# 2  Carol     60   False
# 3  Diana     91    True
# 4    Eve     45   False
#            score
# count   6.000000
# mean   72.166667
# std    17.127950
# min    45.000000
# 25%    63.000000
# 50%    76.000000
# 75%    83.750000
# max    91.000000
